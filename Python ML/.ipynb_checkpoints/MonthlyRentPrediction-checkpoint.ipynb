# %%
from sklearn.linear import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
import pandas as pd
import numpy as np


# Features of this database: [location (1-10); NoOfBedrooms; NoOfBathrooms; Squarefeet; apartmentAge; monthlyRent]
X = [
    [8, 2, 1, 70, 3],
    [9, 3, 2, 120, 1],
    [6, 1, 1, 45, 8],
    [7, 2, 1, 60, 4],
    [5, 3, 2, 100, 10]
]
y = [8500, 12500, 5500, 7800, 9500]  # monthly rent in Rands

model = LinearRegression()
model.fit(X, y)

option = 0

try: 
    while option != 6

    print("===== Kuda Apartment System =====")
    print("1. ")

except: 
    print("Invalid input, enter valid option!!!")
